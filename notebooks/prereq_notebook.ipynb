# %%
print("Hello from Me 🚀")
name = "William"
mood = "excited"
print("{name} is feeling {mood} to be here!")

# %% [markdown]
# # Aliens in the Deep Ocean
#
# ## Where are they?
# - In the deepest darkest depths
#
# ## How long have they been here?
# - Evidence suggests a very long time
#
# ## Appearances in Film and Media:
# - "The Abyss" movie is not fiction - it is a Documentary.
